# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Names-&amp;-IDs" data-toc-modified-id="Names-&amp;-IDs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Names &amp; IDs</a></span></li><li><span><a href="#Problem-#-A" data-toc-modified-id="Problem-#-A-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Problem # A</a></span><ul class="toc-item"><li><span><a href="#A-1" data-toc-modified-id="A-1-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>A-1</a></span></li><li><span><a href="#A-2" data-toc-modified-id="A-2-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>A-2</a></span></li><li><span><a href="#A-3" data-toc-modified-id="A-3-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>A-3</a></span></li><li><span><a href="#A-4" data-toc-modified-id="A-4-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>A-4</a></span></li><li><span><a href="#A-5" data-toc-modified-id="A-5-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>A-5</a></span></li><li><span><a href="#A-6" data-toc-modified-id="A-6-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>A-6</a></span></li></ul></li><li><span><a href="#Problem-#-B" data-toc-modified-id="Problem-#-B-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Problem # B</a></span><ul class="toc-item"><li><span><a href="#B-1" data-toc-modified-id="B-1-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>B-1</a></span></li><li><span><a href="#B-2" data-toc-modified-id="B-2-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>B-2</a></span></li><li><span><a href="#B-3" data-toc-modified-id="B-3-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>B-3</a></span></li><li><span><a href="#B-4" data-toc-modified-id="B-4-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>B-4</a></span></li><li><span><a href="#B-5" data-toc-modified-id="B-5-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>B-5</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Names & IDs

# %%
import math

Group Number= ''

# %%
Name= 'First_Name  Last_Name'    ID= 202012345

# %% [markdown]
# # Problem # A

# %% [markdown]
# ## A-1

# %%
#Answer for A-1
import pandas as pd
df = pd.read_csv('HW5Data1.csv',delimiter=',')
display(df)

rows,cols = df.shape
print(f"Number of rows   : {rows}")
print(f"Number of Columns: {cols}")

print(f"Number of null rows \n{df.count(axis=0)}")

display(df.describe(include='object'))
display(df.describe(exclude='object'))
# Out:
#      Application. ID     Age  Gender Location Parents Edu. Siblings  \
# 0          Ref#12436  23 yrs    Male  Eastern            F       No
# 1          Ref#22094  20 yrs  Female  Western          M+F       No
# 2          Ref#39403  19 yrs  Female  Central          M+F       No
# 3          Ref#43891  16 yrs    Male  Eastern          M+F      Yes
# 4          Ref#57083  19 yrs  Female  Eastern            M       No
# ...              ...     ...     ...      ...          ...      ...
# 4995       Ref#49966  20 yrs    Male  Central            M      Yes
# 4996       Ref#49975  20 yrs  Female  Eastern            F       No
# 4997       Ref#49989  17 yrs  Female  Central            F       No
# 4998       Ref#49997  20 yrs  Female  Central          M+F       No
# 4999       Ref#50007  15 yrs  Female  Central            M      Yes
#
#       RAM-1 Score  RAM-2 Score HS Score School Rank  SOP Admission Status
# 0              54           64      30%         Avg  2.5               No
# ...

# %% [markdown]
# ## A-2

# %%
#Answer for A-2
df.info()
'''There are type inconsistent with age and the high scores. Because both of the should be Numerical'''
df['Age'] = df['Age'].map(lambda x: int(x.replace(" yrs","")))
df['HS Score'] = df['HS Score'].map(lambda x:int(x.replace("%","")))
print(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Application. ID   5000 non-null   object
#  1   Age               5000 non-null   object
#  2   Gender            5000 non-null   object
#  3   Location          5000 non-null   object
#  4   Parents Edu.      5000 non-null   object
#  5   Siblings          5000 non-null   object
#  6   RAM-1 Score       5000 non-null   int64
#  7   RAM-2 Score       5000 non-null   int64
#  8   HS Score          5000 non-null   object
#  9   School Rank       5000 non-null   object
#  10  SOP               5000 non-null   float64
#  11  Admission Status  5000 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 468.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
# ...

# %% [markdown]
# ## A-3

# %%
#Answer for A-3
df.drop('Application. ID',axis=1,inplace=True)
df
# Out:
#       Age  Gender Location Parents Edu. Siblings  RAM-1 Score  RAM-2 Score  \
# 0      23    Male  Eastern            F       No           54           64
# 1      20  Female  Western          M+F       No           34           27
# 2      19  Female  Central          M+F       No           48           38
# 3      16    Male  Eastern          M+F      Yes           81           97
# 4      19  Female  Eastern            M       No           56           67
# ...   ...     ...      ...          ...      ...          ...          ...
# 4995   20    Male  Central            M      Yes           25           20
# 4996   20  Female  Eastern            F       No           59           70
# 4997   17  Female  Central            F       No           55           66
# 4998   20  Female  Central          M+F       No           54           64
# 4999   15  Female  Central            M      Yes           53           63
#
#       HS Score School Rank  SOP Admission Status
# ...

# %% [markdown]
# ## A-4

# %%
#Answer for A-4
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
numeric_cols = df.select_dtypes(exclude='object').columns
non_numeric_cols = list(df.select_dtypes(include='object').columns)
non_numeric_cols.remove('Admission Status')

for i in range(len(numeric_cols)):
    plt.subplot(len(numeric_cols),1,i+1)
    sns.histplot(x=numeric_cols[i] , hue='Admission Status' ,data=df)
plt.show()

plt.figure(figsize=(10,10))
for i in range(len(non_numeric_cols)):
    plt.subplot(len(non_numeric_cols),1,i+1)
    sns.histplot(x=non_numeric_cols[i] , hue='Admission Status' ,data=df)
plt.show()

# %% [markdown]
# ## A-5

# %%
#Answer for A-5

plt.figure(figsize=(20,20))
rows = len(numeric_cols)
cols = len(non_numeric_cols)
for row in range(len(numeric_cols) - 1):
    for col in range(row+1,len(numeric_cols)):
        plt.subplot(rows,rows,5*row + col+1)
        sns.scatterplot(y = numeric_cols[col],x= numeric_cols[row] ,data = df,hue = 'Admission Status')


plt.show()
'''
    Yes. When the RAM-1 Score is increasing also RAM-2 Score is increasing at some point.
'''
plt.figure(figsize=(20,20))
for row in range(len(numeric_cols)):
    for col in range(len(non_numeric_cols)):
        plt.subplot(rows,cols,cols*row + col+1)
        sns.violinplot(y = numeric_cols[col],x= non_numeric_cols[row] ,data = df,hue = 'Admission Status')


plt.show()


plt.figure(figsize=(10,10))
sns.catplot(y='Admission Status',hue = 'Parents Edu.',col = 'School Rank',row = 'Siblings',kind="count" ,data=df )
plt.show()

"""
    Count of students siblings is currently enrolled, and both parents are educated is shown from the second row and brown color column. As we can see there almost every student that satisfy the condition have the admission according to the graphs
"""

plt.figure(figsize=(10,10))
sns.catplot(y='HS Score',x ='School Rank' ,hue = 'Parents Edu.',col = 'Admission Status',row = 'Siblings',kind="boxen" ,data=df )
plt.show()

"""
    Yes.As we can see in the second figure it shows it is not always HS score high from High school rank
"""

plt.figure(figsize=(10,10))
sns.catplot(y='RAM-1 Score',x ='RAM-2 Score' ,hue = 'Parents Edu.',col = 'Admission Status',row = 'Siblings',kind="point" ,data=df )
plt.show()

# %% [markdown]
# ## A-6

# %%
#Answer for A-6
ctab = pd.crosstab(df['Location'],df['Gender'])

display(pd.concat([ctab.idxmax(), ctab.max()], axis=1))
display(pd.concat([ctab.idxmin(), ctab.min()], axis=1))

df['Admission_num'] = df['Admission Status'].apply(lambda x: 1 if x.lower() == 'yes' else 0)
pTable=df.pivot_table(values=['Admission_num'],
                       index=['Location'],
                      columns=['Gender'],
                       aggfunc=sum)


display(pd.concat([pTable.idxmax(), pTable.max()], axis=1))
display(pd.concat([pTable.idxmin(), pTable.min()], axis=1))



pTable=df.pivot_table(values=['Admission_num'],
                       index=['Parents Edu.','School Rank'],
                      columns=['Siblings'])
display(pTable.Admission_num.Yes)
# Out:
#               0    1
# Gender
# Female  Central  880
# Male    Western  848
#               0    1
# Gender
# Female  Eastern  806
# Male    Central  808
#                             0    1
#               Gender
# Admission_num Female  Central  597
#               Male    Western  571
#                             0    1
#               Gender
# Admission_num Female  Eastern  535
#               Male    Central  548
# Parents Edu.  School Rank
# F             Avg            0.566038
#               High           0.698925
#               Low            0.600000
# M             Avg            0.573034
#               High           0.709434
#               Low            0.578947
# M+F           Avg            1.000000
#               High           1.000000
#               Low            1.000000
# Name: Yes, dtype: float64

# %% [markdown]
# # Problem # B

# %% [markdown]
# ## B-1

# %%
#Answer for B-1
df = pd.read_csv('HW5Data2.csv',delimiter=",")
rows,cols = df.shape
print(f"Number of rows   : {rows}")
print(f"Number of Columns: {cols}")

print(df.count(axis=0)) # Each columns have 3500 rows means there are no missing values

display(df.describe(include='object'))
display(df.describe(exclude='object'))
# Out:
# Number of rows   : 3500
# Number of Columns: 10
# Gender      3500
# Location    3500
# Quiz-1      3500
# Quiz-2      3500
# Quiz-3      3500
# Quiz-4      3500
# Major-1     3500
# Major-2     3500
# Major-3     3500
# Final       3500
# dtype: int64
#        Gender Location
# count    3500     3500
# unique      2        7
# top      Male  Madinah
# freq     1756      519
#             Quiz-1       Quiz-2       Quiz-3       Quiz-4      Major-1  \
# count  3500.000000  3500.000000  3500.000000  3500.000000  3500.000000
# mean     12.414571    14.814857    14.924286    12.523714    55.954571
# std       5.618516     6.001572     6.094121     5.612041    21.552887
# min       0.000000     5.000000     5.000000     0.000000    12.000000
# 25%       8.000000    10.000000    10.000000     8.000000    38.000000
# 50%      12.000000    15.000000    15.000000    13.000000    56.000000
# 75%      17.000000    20.000000    20.000000    17.000000    74.000000
# ...

# %% [markdown]
# ## B-2

# %%
#Answer for B-2
df.info()
'''There is no inconsistency'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Gender    3500 non-null   object
#  1   Location  3500 non-null   object
#  2   Quiz-1    3500 non-null   int64
#  3   Quiz-2    3500 non-null   int64
#  4   Quiz-3    3500 non-null   int64
#  5   Quiz-4    3500 non-null   int64
#  6   Major-1   3500 non-null   int64
#  7   Major-2   3500 non-null   int64
#  8   Major-3   3500 non-null   int64
#  9   Final     3500 non-null   int64
# dtypes: int64(8), object(2)
# memory usage: 273.6+ KB

# %% [markdown]
# ## B-3

# %%
#Answer for B-3
from sklearn.preprocessing import StandardScaler
columns = (df.iloc[:,2:]).columns
scaler = StandardScaler()

for col in columns:
    scaler.fit(df[[col]])
    df[col]=scaler.transform(df[[col]])

df
# Out:
#       Gender Location    Quiz-1    Quiz-2    Quiz-3    Quiz-4   Major-1  \
# 0       Male   Jeddah  0.816245  0.364147  1.489470  0.619522  2.043890
# 1     Female   Jeddah -0.429814  1.030734 -0.151690 -0.806188 -1.854057
# 2     Female   Jeddah -0.963839  1.030734  1.325354 -0.984402 -0.044296
# 3       Male   Dammam  1.706287 -0.802381  0.997122 -0.093333  1.115807
# 4     Female   Dammam  1.528278  0.030853  0.340658  0.975949  1.162211
# ...      ...      ...       ...       ...       ...       ...       ...
# 3495  Female   Riyadh  0.460228  1.697322  0.833006  0.441308  1.440636
# 3496    Male   Dammam  0.460228 -0.135793  0.340658 -0.806188 -0.369125
# 3497    Male   Riyadh  1.350270  1.364028  0.833006  0.975949  0.698170
# 3498  Female   Riyadh -0.429814  0.197500 -1.464618 -0.093333  0.326937
# 3499    Male   Dammam -0.073797 -0.469087  1.489470 -1.340829 -0.879570
#
#        Major-2   Major-3     Final
# 0     1.658954  1.323202  1.493295
# ...

# %% [markdown]
# ## B-4

# %%
#Answer for B-4
score_df = df.loc[:,columns]
corr = score_df.corr(method='pearson')
display(corr)
corr.sort_values('Final',ascending=False)
'''
    1. Major-2
    2. Major-1
    3. Major-3
'''
max_index = ""
max_col = ""
max_val = -1

rows = corr.index
cols = corr.columns

for row in rows:
    for col in columns:
        if row == col:
            continue
        if max_val < abs(corr.loc[row,col]):
            max_val = abs(corr.loc[row,col])
            max_index = row
            max_col = col

print(f"Highly correlated pair of columns are {max_col} and {max_index}")
# Out:
#            Quiz-1    Quiz-2    Quiz-3    Quiz-4   Major-1   Major-2   Major-3  \
# Quiz-1   1.000000 -0.019810 -0.014291  0.682592  0.790215  0.790874  0.789688
# Quiz-2  -0.019810  1.000000 -0.003306 -0.021923 -0.025164 -0.021010 -0.023346
# Quiz-3  -0.014291 -0.003306  1.000000 -0.019096 -0.023358 -0.032447 -0.029954
# Quiz-4   0.682592 -0.021923 -0.019096  1.000000  0.794112  0.798142  0.790277
# Major-1  0.790215 -0.025164 -0.023358  0.794112  1.000000  0.921456  0.920826
# Major-2  0.790874 -0.021010 -0.032447  0.798142  0.921456  1.000000  0.926736
# Major-3  0.789688 -0.023346 -0.029954  0.790277  0.920826  0.926736  1.000000
# Final    0.838695 -0.026549 -0.026751  0.876668  0.961379  0.970803  0.938199
#
#             Final
# Quiz-1   0.838695
# Quiz-2  -0.026549
# Quiz-3  -0.026751
# Quiz-4   0.876668
# Major-1  0.961379
# Major-2  0.970803
# Major-3  0.938199
# Final    1.000000
# Highly correlated pair of columns are Final and Major-2

# %% [markdown]
# ## B-5

# %%
#Answer for B-5
num_columns = df.select_dtypes(exclude='object').columns
pca_input_columns=num_columns.drop(['Final'])

from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=2) # get pca model
principalComponents = pca.fit_transform(df[pca_input_columns]) # get two components

df['PC1'] = principalComponents[:,0]
df['PC2'] = principalComponents[:,1]

df
temp_df1 = pd.read_csv('HW5Data2.csv',delimiter=",")
temp_df = df
temp_df.drop('Final',axis=1)

temp_df['Final'] = temp_df1['Final']
temp_df
plt.figure()
temp_df['finalDef'] = temp_df['Final'].apply(lambda x : 'final>85' if x > 85 else '84>final>65' if x >65 else 'final<65')

sns.relplot(x='PC1', y='PC2',palette=['g','r', 'b'], hue='finalDef',data=df)
sns.relplot(x='PC1', y='PC2',palette=['g','r', 'b'], hue='finalDef',col='Gender',data=df)
sns.relplot(x='PC1', y='PC2',palette=['g','r', 'b'], hue='finalDef',col='Location',data=df)


plt.show()


for ind,var in enumerate(pca.explained_variance_ratio_):
    print(f'The variance captured by pca {ind+1} is: {var*100: 0.2f}%')


pca_1_coefficients=np.round(pca.components_[0],4)

zipList=list(zip(pca_input_columns,pca_1_coefficients))
ndf=pd.DataFrame.from_records(zipList,columns=['field','coeff'])

display(ndf)
# Out:
# The variance captured by pca 1 is:  80.63%
# The variance captured by pca 2 is:  18.85%
#      field   coeff
# 0   Quiz-1 -0.0535
# 1   Quiz-2  0.0019
# 2   Quiz-3  0.0021
# 3   Quiz-4 -0.0537
# 4  Major-1 -0.0588
# 5  Major-2 -0.0589
# 6  Major-3 -0.0588
# 7      PC1  0.9919
# 8      PC2 -0.0000
