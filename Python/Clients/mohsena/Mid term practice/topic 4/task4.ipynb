# %%
import pandas as pd
df = pd.read_excel('HW3_Data_A.xlsx')
display(df.sample(15))
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 84           3                NaN  mitsubishi       gas      turbo
# 140          2               83.0      subaru       gas        std
# 111          0              161.0      peugot       gas        std
# 189          3                NaN  volkswagen       gas        std
# 138          2               83.0      subaru       gas        std
# 87           1              125.0  mitsubishi       gas      turbo
# 203         -1               95.0       volvo    diesel      turbo
# 117          0              161.0      peugot       gas      turbo
# 27           1              148.0       dodge       gas      turbo
# 115          0              161.0      peugot       gas        std
# 175         -1               65.0      toyota       gas        std
# 51           1              104.0       mazda       gas        std
# 30           2              137.0       honda       gas        std
# ...

# %%
columns  = df.columns
columns

rows = df.index
rows
# 205 - df.count(axis=0)
df.count(axis=0)
# Out:
# ID                           50000
# year                         50000
# loan_limit                   48838
# Gender                       50000
# approv_in_adv                49724
# loan_type                    50000
# loan_purpose                 49950
# Credit_Worthiness            50000
# open_credit                  50000
# business_or_commercial       50000
# loan_amount                  50000
# rate_of_interest             42091
# Interest_rate_spread         42005
# Upfront_charges              40964
# term                         49988
# Neg_ammortization            49955
# interest_only                50000
# lump_sum_payment             50000
# property_value               50000
# construction_type            50000
# occupancy_type               50000
# Secured_by                   50000
# total_units                  50000
# income                       46381
# credit_type                  50000
# Credit_Score                 50000
# co-applicant_credit_type     50000
# ...

# %%
numeric_cols = df.select_dtypes(exclude='object').columns
df[numeric_cols].describe()

# %%
df.describe(include='number')
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
mask = df['make'] == 'toyota'
(df.loc[mask,:]).describe(include='object')
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count       32        32         32           32         32           32
# unique       1         2          2            2          5            3
# top     toyota       gas        std         four  hatchback          fwd
# freq        32        29         31           18         14           16
#
#        engine-location engine-type num-of-cylinders fuel-system
# count               32          32               32          32
# unique               1           2                2           3
# top              front         ohc             four        mpfi
# freq                32          26               28          16

# %%
mask = (df['fuel-type'] == 'gas') & (df['horsepower'] < 130) & (df['horsepower'] > 100)
(df.loc[mask,'price']).max() - (df.loc[mask,'price']).min()
# Out:
# 16876.0

# %%
mask = df['length'] >= 170
ndf = df.loc[mask,:]
length = ndf.shape[0]
two = df.loc[(df['num-of-doors'] == 'two') & (df['length'] >= 170) ,:].shape[0]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('HW3_Data_B.csv',delimiter=",")

plt.figure(figsize=(9,4),dpi=200)
sns.lineplot(y='loan_amount',x='property_value',hue = 'Status',data=df)
plt.show()

# %%
sns.lineplot(y='loan_amount',x='property_value',hue = 'Status',style ='Region' ,data=df)
plt.show()

# %%
# regions = df['Region'].unique().tolist()
# for region in regions:
#     sns.lineplot(y='loan_amount',x='property_value',hue = 'Status',data=df.loc[df['Region'] == region])


sns.catplot(kind = 'point', y='loan_amount',x='property_value',col = 'Region',hue = 'Status',data=df)
plt.show()
